# %%
import os

import xarray as xr
import matplotlib.pyplot as plt
from cartopy import crs as ccrs
import cartopy.feature as cfeature

# %% [markdown]
# ## Open Datasets

# %%
data_dir = './data/processed/mhw_stats_outputs'
no_occ_da = xr.open_dataset(
    os.path.join(data_dir, 'no_occurrences_CBay_geopolar.nc')
    ).total_no_occurrences

avg_dur_da = xr.open_dataset(
    os.path.join(data_dir, 'average_mhw_duration_CBay_geopolar.nc')
    ).avg_duration

avg_max_int_da = xr.open_dataset(
    os.path.join(data_dir, 'average_max_intensity_CBay_geopolar.nc')
    ).avg_max_intensity


avg_rate_on_da = xr.open_dataset(
    os.path.join(data_dir, 'average_rate_onset_CBay_geopolar.nc')
    ).avg_onset_rate

avg_rate_off_da = xr.open_dataset(
    os.path.join(data_dir, 'average_rate_decline_CBay_geopolar.nc')
    ).avg_decline_rate

avg_annual_events_da = xr.open_dataset(
    os.path.join(data_dir, 'average_no_annual_events_CBay_geopolar.nc')
    ).avg_no_annual_events

avg_cum_intensity_da = xr.open_dataset(
    os.path.join(data_dir, 'average_cum_intensity_CBay_geopolar.nc')
    ).avg_cum_intensity

# %% [markdown]
# ## Plot

# %%
# directory in which to save the figures
output_dir = './figures/mhw_maps'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %%
fig, ax = plt.subplots(subplot_kw={'projection': ccrs.PlateCarree()})

fig.set_size_inches(18, 7)

# Add background features
ax.add_feature(cfeature.COASTLINE, alpha=0.3)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.RIVERS)
# ax.coastlines()

# Add and format gridlines. Remove top and right labels
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=1, color='gray', alpha=0.2, linestyle='--')
gl.top_labels, gl.right_labels = False, False

no_occ_da.plot(ax=ax)  # , legend_kwds={'label': "Total # of Occurrences"})
# no_occ_da.plot(ax=ax, markersize=8, cmap='bwr', legend=True, 
#                      vmin=-5, vmax=5,)  # legend_kwds={'label': "SST Difference (Geopolar - Ship)"},)

plt.title('Total number of Occurrences')

# Save the figure
plt.savefig(os.path.join(output_dir, 'no_occurrences_CBay_geopolar.png'),
            bbox_inches='tight')
# plt.close()

# %%
fig, ax = plt.subplots(subplot_kw={'projection': ccrs.PlateCarree()})

fig.set_size_inches(18, 7)

# Add background features
ax.add_feature(cfeature.COASTLINE, alpha=0.3)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.RIVERS)
# ax.coastlines()

# Add and format gridlines. Remove top and right labels
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=1, color='gray', alpha=0.2, linestyle='--')
gl.top_labels, gl.right_labels = False, False

avg_dur_da.plot(ax=ax)  # , legend_kwds={'label': "Total # of Occurrences"})
# no_occ_da.plot(ax=ax, markersize=8, cmap='bwr', legend=True, 
#                      vmin=-5, vmax=5,)  # legend_kwds={'label': "SST Difference (Geopolar - Ship)"},)

plt.title('Average Duration')

# Plot
plt.savefig(os.path.join(output_dir, 'average_mhw_duration_CBay_geopolar.png'),
            bbox_inches='tight')
# plt.close()

# %%
fig, ax = plt.subplots(subplot_kw={'projection': ccrs.PlateCarree()})

fig.set_size_inches(18, 7)

# Add background features
ax.add_feature(cfeature.COASTLINE, alpha=0.3)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.RIVERS)
# ax.coastlines()

# Add and format gridlines. Remove top and right labels
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=1, color='gray', alpha=0.2, linestyle='--')
gl.top_labels, gl.right_labels = False, False

avg_max_int_da.plot(ax=ax, cmap='OrRd')  # , legend_kwds={'label': "Total # of Occurrences"})
# no_occ_da.plot(ax=ax, markersize=8, cmap='bwr', legend=True, 
#                      vmin=-5, vmax=5,)  # legend_kwds={'label': "SST Difference (Geopolar - Ship)"},)

plt.title('Average Peak Intensity')

# Plot
plt.savefig(os.path.join(output_dir, 'average_max_intensity_CBay_geopolar.png'), 
            bbox_inches='tight')
# plt.close()

# %%
print('onset max/min', avg_rate_on_da.min().values, avg_rate_on_da.max().values)
print('decline max/min', avg_rate_off_da.min().values, avg_rate_off_da.max().values)
# Out:
# onset max/min 0.24963869741934078 0.44587514287691327
# decline max/min 0.1810323519067038 0.46305495698342486

# %%
fig, ax = plt.subplots(subplot_kw={'projection': ccrs.PlateCarree()})

fig.set_size_inches(18, 7)

# Add background features
ax.add_feature(cfeature.COASTLINE, alpha=0.3)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.RIVERS)
# ax.coastlines()

# Add and format gridlines. Remove top and right labels
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=1, color='gray', alpha=0.2, linestyle='--')
gl.top_labels, gl.right_labels = False, False

avg_rate_on_da.plot(ax=ax, vmin=0.2, vmax=0.5)  # , legend_kwds={'label': "Total # of Occurrences"})
# no_occ_da.plot(ax=ax, markersize=8, cmap='bwr', legend=True, 
#                      vmin=-5, vmax=5,)  # legend_kwds={'label': "SST Difference (Geopolar - Ship)"},)

plt.title('Average Rate Onset')

# Plot
plt.savefig(os.path.join(output_dir, 'average_rate_onset_CBay_geopolar.png'),
           bbox_inches='tight')
# plt.close()

# %%
fig, ax = plt.subplots(subplot_kw={'projection': ccrs.PlateCarree()})

fig.set_size_inches(18, 7)

# Add background features
ax.add_feature(cfeature.COASTLINE, alpha=0.3)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.RIVERS)
# ax.coastlines()

# Add and format gridlines. Remove top and right labels
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=1, color='gray', alpha=0.2, linestyle='--')
gl.top_labels, gl.right_labels = False, False

avg_rate_off_da.plot(ax=ax, vmin=0.2, vmax=0.5)  # , legend_kwds={'label': "Total # of Occurrences"})
# no_occ_da.plot(ax=ax, markersize=8, cmap='bwr', legend=True, 
#                      vmin=-5, vmax=5,)  # legend_kwds={'label': "SST Difference (Geopolar - Ship)"},)

plt.title('Average Rate Decline')

# Plot
plt.savefig(os.path.join(output_dir, 'average_rate_decline_CBay_geopolar.png'),
           bbox_inches='tight')
# plt.close()

# %%
fig, ax = plt.subplots(subplot_kw={'projection': ccrs.PlateCarree()})

fig.set_size_inches(18, 7)

# Add background features
ax.add_feature(cfeature.COASTLINE, alpha=0.3)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.RIVERS)
# ax.coastlines()

# Add and format gridlines. Remove top and right labels
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=1, color='gray', alpha=0.2, linestyle='--')
gl.top_labels, gl.right_labels = False, False

avg_annual_events_da.plot(ax=ax, cmap='OrRd')  # , legend_kwds={'label': "Total # of Occurrences"})
# no_occ_da.plot(ax=ax, markersize=8, cmap='bwr', legend=True, 
#                      vmin=-5, vmax=5,)  # legend_kwds={'label': "SST Difference (Geopolar - Ship)"},)

plt.title('Average No Annual Events')

# Plot
plt.savefig(os.path.join(output_dir, 'average_no_annual_events_CBay_geopolar.png'), 
            bbox_inches='tight')
# plt.close()

# %%
fig, ax = plt.subplots(subplot_kw={'projection': ccrs.PlateCarree()})

fig.set_size_inches(18, 7)

# Add background features
ax.add_feature(cfeature.COASTLINE, alpha=0.3)
ax.add_feature(cfeature.BORDERS, linestyle=':')
ax.add_feature(cfeature.RIVERS)
# ax.coastlines()

# Add and format gridlines. Remove top and right labels
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                  linewidth=1, color='gray', alpha=0.2, linestyle='--')
gl.top_labels, gl.right_labels = False, False

avg_cum_intensity_da.plot(ax=ax, cmap='OrRd')  # , legend_kwds={'label': "Total # of Occurrences"})
# no_occ_da.plot(ax=ax, markersize=8, cmap='bwr', legend=True, 
#                      vmin=-5, vmax=5,)  # legend_kwds={'label': "SST Difference (Geopolar - Ship)"},)

plt.title('Average Cumulative Intensity')

# Plot
plt.savefig(os.path.join(output_dir, 'average_cum_intensity_CBay_geopolar.png'), 
            bbox_inches='tight')
# plt.close()

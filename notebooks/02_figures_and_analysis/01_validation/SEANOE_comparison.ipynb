# %% [markdown]
# Major takeaway:
# - Don't think it makes a lot of sense to compare, since the baseline periods are so different (1985-2023)

# %%
import os

import xarray as xr

# %%
REPO_ROOT = '/Users/rwegener/repos/chesapeake_mhw'

# %%
ds = xr.open_dataset(os.path.join(REPO_ROOT, 'data/raw', '109516.nc'))

# %%
ds.temperature_surface
# Out:
# <xarray.DataArray 'temperature_surface' (time: 12, latitude: 567, longitude: 348)>
# [2367792 values with dtype=float32]
# Coordinates:
#   * latitude   (latitude) float64 36.55 36.56 36.56 36.57 ... 39.6 39.6 39.61
#   * longitude  (longitude) float64 -77.4 -77.39 -77.39 ... -75.04 -75.03 -75.03
#   * time       (time) datetime64[ns] 2000-01-16T05:00:00 ... 2000-12-15T19:00:00
# Attributes:
#     long_name:     Potential temperature at the surface
#     units:         Celsius
#     short_name:    T_s
#     grid_mapping:  crs
